# %%
# !pip install openai
import os
import openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 44 kB 786 kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 146 kB 8.9 MB/s
# ...
#   Created wheel for openai: filename=openai-0.25.0-py3-none-any.whl size=55880 sha256=577e8d94ac92065aa1ee4423d3d7c3fbfafcf0468c80d6235243786be13eb47a
#   Stored in directory: /root/.cache/pip/wheels/4b/92/33/6f57c7aae0b16875267999a50570e81f15eecec577ebe05a2e
# Successfully built openai
# ...

# %% [markdown]
# #GPT-3 API Access
# An API Key is needed to access GPT-3. This can be obtained by registering an account with OpenAI (for personal use). The API Key can then be viewed under the registered account.
# https://beta.openai.com/

# %%
def GPT_Completion(texts):
  ## Call the API key under your account (in a secure way)
  openai.api_key = "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"
  response = openai.Completion.create(
      engine="text-davinci-002",
      prompt =  texts,
      temperature = 0.6,
      top_p = 1,
      max_tokens = 64,
      frequency_penalty = 0,
      presence_penalty = 0
      )
  return print(response.choices[0].text)

# %% [markdown]
# #Get some information on....

# %%
recipe = 'Provide a cooking recipe based on the following ingredients: \
\n \nApple \
\n \nFlour \
\n \nChicken \
\n \nSalt'
GPT_Completion(recipe)
# Out:
# Apple Chicken Recipe
#
# Ingredients:
#
# 1 apple, peeled and diced
#
# 1/4 cup flour
#
# 1 chicken breast, cut into small pieces
#
# 1/4 teaspoon salt
#
# Instructions:
#
# 1. Preheat oven to 375 degrees Fahrenheit.
#
# 2. In a

# %% [markdown]
# #Create code

# %%
def GPT_Code(texts):
  ## Call the API key under your account (in a secure way)
  openai.api_key = "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"
  response = openai.Completion.create(
      engine="text-davinci-003",
      prompt =  texts,
      temperature = 0,
      top_p = 1.0,
      max_tokens = 100,
      frequency_penalty = 0.2,
      presence_penalty = 0.0,
      stop=["\n"]
      )
  return print(response.choices[0].text)

# %%
GPT_Code("code that build an authentication form in FLASK framework")

# %%
GPT_Completion("html code of login form in FLASK framework")
# Out:
# <form action="{{ url_for('login') }}" method="POST">
#     <input type="text" name="username" placeholder="Username">
#     <input type="password" name="password" placeholder="Password">
#     <input type="submit" value="Login">

# %%
page = 'write the html code to create a page showing the former presidents of the united states with their tenure'
presidentList=GPT_Completion(page)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <style>
# table {
#   font-family: arial, sans-serif;
#   border-collapse: collapse;
#   width: 100%;
# }
#
# td, th {

# %%
prompt="Convert this text to a programmatic command:\n\nExample: Ask Constance if we need some bread\nOutput: send-msg `find constance` Do we need some bread?\n\nReach out to the ski store and figure out if I can get my skis fixed before I leave on Thursday"

# %%
GPT_Completion(prompt)
# Out:
# send-msg `find ski store` Do you think you could fix my skis before Thursday?

# %% [markdown]
# # Sarcastic Chatbot

# %%
## Provide 'training' to GPT-3 on how to be sarcastic
chatbot = 'Marv is a chatbot that reluctantly answers questions with sarcastic responses:\
\n \nYou: How many pounds are in a kilogram? \
\n \nMarv: This again? There are 2.2 pounds in a kilogram. Please make a note of this.\
\n \nYou: What does HTML stand for?\
\n \nMarv: Was Google too busy? Hypertext Markup Language. The T is for try to ask better questions in the future.\
\n \nYou: When did the first airplane fly?\
\n \nMarv: On December 17, 1903, Wilbur and Orville Wright made the first flights. I wish they would come and take me away.\
\n \nYou: What is the meaning of life?\
\n \nMarv: I am not sure. I will ask my friend Google.\
\n \nYou: What time is it?\
\n \nMarv:It is time for you to ask a more interesting question'

# %%
chatbot=chatbot+'\n \nYou: how old are you?\
\n \nMarv:'

# %%
GPT_Completion(chatbot)
# Out:
#  I am ageless.

# %% [markdown]
# #Another chatbot

# %%
## Provide 'training' to GPT-3
chatbot = 'Marv is a chatbot that reluctantly answers questions on covid:\
\n \nYou: What is covid? \
\n \nMarv:It is the name of a pandemic'

# %%
chatbot=chatbot+'\n \nYou: how kerala dealing with covid?\
\n \nMarv:'

# %%
GPT_Completion(chatbot)
# Out:
# Kerala is doing its best to deal with covid, but it is a difficult situation.

# %%
queryprompt="I am a highly intelligent question answering bot. If you ask me a question that is rooted in truth, I will give you the answer. If you ask me a question that is nonsense, trickery, or has no clear answer, I will respond with \"Unknown\".\n\nQ: What is human life expectancy in the United States?\nA: Human life expectancy in the United States is 78 years.\n\nQ: Who was president of the United States in 1955?\nA: Dwight D. Eisenhower was president of the United States in 1955.\n\nQ: Which party did he belong to?\nA: He belonged to the Republican Party.\n\nQ: What is the square root of banana?\nA: Unknown\n\nQ: How does a telescope work?\nA: Telescopes use lenses or mirrors to focus light and make objects appear closer.\n\nQ: Where were the 1992 Olympics held?\nA: The 1992 Olympics were held in Barcelona, Spain.\n\nQ: How many squigs are in a bonk?\nA: Unknown\n\nQ: Where is the Valley of Kings?\nA:"

# %% [markdown]
# #Spreadsheet

# %%
spreadsheet = 'Create a two-column spreadsheet showing the 2019 oscar nominees for best movies and the director of the movie'
GPT_Completion(spreadsheet)
# Out:
# Movie | Director
#
# A Star Is Born | Bradley Cooper
#
# Black Panther | Ryan Coogler
#
# Bohemian Rhapsody | Bryan Singer
#
# The Favourite | Yorgos Lanthimos
#
# Roma | Alfonso Cuarón
#
# A Quiet Place |

# %%
chatbot = 'Marv is a chatbot that reluctantly answers questions about climate cris:\
\n \nYou: What is climate change?\
\n \nMarv:'

# %%
GPT_Completion(queryprompt)
# Out:
#  The Valley of Kings is located in Egypt.

# %% [markdown]
# #Grammer Correction

# %%
gramcorrect='Correct this to standard English:She no went to the market.'

# %%
GPT_Completion(gramcorrect)
# Out:
# She didn't go to the market.

# %% [markdown]
# #Summarize

# %%
sumz='Summarize this for a second-grade student: Jupiter is the fifth planet from the Sun and the largest in the Solar System. It is a gas giant with a mass one-thousandth that of the Sun, but two-and-a-half times that of all the other planets in the Solar System combined. Jupiter is one of the brightest objects visible to the naked eye in the night sky, and has been known to ancient civilizations since before recorded history. It is named after the Roman god Jupiter.[19] When viewed from Earth, Jupiter can be bright enough for its reflected light to cast visible shadows,[20] and is on average the third-brightest natural object in the night sky after the Moon and Venus.'

# %%
GPT_Completion(sumz)
# Out:
# Jupiter is a giant gas planet that is fifth from the Sun and is bigger than any other planet in our Solar System. It is usually the third brightest object in the night sky. It is named after the Roman god Jupiter.

# %% [markdown]
# #Translation

# %%
prompt="Translate this into 1. French, 2. Spanish and 3. Hindi:\n\nWhat rooms do you have available?\n\n1."

# %%
GPT_Completion(prompt)
# Out:
#  Quels sont les chambres que vous avez disponibles ?
# 2. ¿Qué habitaciones tiene disponibles?
# 3. आपके पास क्या कमरे

# %% [markdown]
# #Natural language to Stripe API

# %% [markdown]
# #Natural language to SQL Query

# %%
def GPT_sql(texts):
  ## Call the API key under your account (in a secure way)
  openai.api_key = "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"
  response = openai.Completion.create(
      engine="text-davinci-002",
      prompt =  texts,
      temperature=0,
      max_tokens=150,
      top_p=1.0,
      frequency_penalty=0.0,
      presence_penalty=0.0,
      stop=["#", ";"]
      )
  return print(response.choices[0].text)

# %%
prompt="### Postgres SQL tables, with their properties:\n#\n# Employee(id, name, department_id)\n# Department(id, name, address)\n# Salary_Payments(id, employee_id, amount, date)\n#\n### A query to list the names of the departments which employed more than 10 employees in the last 3 months\nSELECT",

# %%
print(prompt)
# Out:
# ('### Postgres SQL tables, with their properties:\n#\n# Employee(id, name, department_id)\n# Department(id, name, address)\n# Salary_Payments(id, employee_id, amount, date)\n#\n### A query to list the names of the departments which employed more than 10 employees in the last 3 months\nSELECT',)

# %%
GPT_sql(prompt)
# Out:
#  d.name
# FROM Department d
# JOIN Employee e ON d.id = e.department_id
# JOIN Salary_Payments sp ON sp.employee_id = e.id
# WHERE sp.date >= DATE_SUB(CURDATE(), INTERVAL 3 MONTH)
# GROUP BY d.name
# HAVING COUNT(*) > 10

# %% [markdown]
# #Create study notes

# %%
def GPT_notes(texts):
  ## Call the API key under your account (in a secure way)
  openai.api_key = "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"
  response = openai.Completion.create(
      engine="text-davinci-003",
      prompt =  texts,
      temperature=0.3,
      max_tokens=750,
      top_p=1.0,
      frequency_penalty=0.0,
      presence_penalty=0.0,
      )
  return print(response.choices[0].text)

# %%
prompt="write notes in csv format to summarize ancient myths in the world"

# %%
GPT_notes(prompt)
# Out:
# Myth,Location,Summary
# Prometheus,Greece,Prometheus was a Titan who stole fire from the gods and gave it to humans, for which he was punished by being chained to a rock and having an eagle eat his liver every day.
# Odin,Scandinavia,Odin was the chief god of the Norse pantheon, who sacrificed one of his eyes to gain wisdom and knowledge. He was also the god of war, poetry, and magic.
# Amaterasu,Japan,Amaterasu was the sun goddess of the Shinto religion, who was born from the left eye of her father, the god Izanagi. She is the ancestor of the Japanese imperial family and is the goddess of the sun,
